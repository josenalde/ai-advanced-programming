# %% [markdown]
# ### Contexto do Problema
# No ano de 2048, a estação espacial orbital SpaceTec-Info EAJ sofreu uma descompressão parcial após um impacto de micrometeorito. Todos os 1.000 tripulantes a bordo foram evacuados para as cápsulas de emergência. Seu objetivo como Desenvolvedor de Sistemas Inteligentes é construir um modelo de IA preditivo que determine quais tripulantes conseguiram ser resgatados (1) ou ficaram perdidos na órbita (0).
#
# A base de dados é balanceada e contém informações socioeconômicas, técnicas e de localização da tripulação no momento do impacto.

# %% [markdown]
# ## Carregue a base de dados e veja se está tudo certo, exibindo as 10 primeiras linhas. Quantos registros e colunas possui a base?

# %% [markdown]
# ## 1. Análise Exploratória de Dados (AED ou EDA (Exploratory Data Analysis)):
# ### 1.1 Exiba as colunas e tipos de dados, comparando com o dicionário de dados fornecido. O objetivo é entender os dados

# %% [markdown]
# ### 1.2 Verifique se existem colunas com dados ausentes

# %% [markdown]
# ### 1.3 Exiba estatísticas descritivas básicas (mean, std, min, max) das informações numéricas

# %% [markdown]
# ### 1.4 Para as informações categóricas, exiba os valores únicos em cada coluna

# %% [markdown]
# ### 1.5 Gere 2 gráficos de análise de como está relacionado a taxa de resgate por modulo_estacao e por traje_pressurizado

# %% [markdown]
# ### 1.6 Gere um mapa de calor ou tabela de correlação, mostrando a relação da target com as informações numéricas. O objetivo é ver o impacto delas na variável target

# %% [markdown]
# ### 1.7 Descarte variáveis irrelevantes ou redundantes (ex: id_passageiro).

# %% [markdown]
# ## 2. Transformações e Engenharia de Features

# %% [markdown]
# ### 2.1 Trate os valores nulos por imputação de mediana

# %% [markdown]
# ### 2.2 Crie uma nova feature sintética a partir do nome, com o título da pessoa (ex: extrair o título como Dra., Ten., Eng.).

# %% [markdown]
# ### 2.3 Padronize as variáveis numéricas com StandardScaler

# %% [markdown]
# ## 3. Seleção de Modelos

# %% [markdown]
# ### 3.1 Divida a base inicial em Treino (80%) e Teste Final de Avaliação (20%).

# %% [markdown]
# ### 3.2 Treinar e comparar a acurácia média usando K-Fold Cross-Validation (K=10) para os seguintes algoritmos:
#
# - Regressão Logística (Logistic Regression)
#
# - Árvore de Decisão (Decision Tree)
#
# - Floresta Aleatória (Random Forest)
#
# - K-Vizinhos Mais Próximos (K-Nearest Neighbors - KNN)
#
# - Máquina de Vetores de Suporte (SVM)
#
# - Redes Neurais MLP

# %% [markdown]
# ### 3.3 Ranqueie e Selecione o modelo de melhor desempenho na etapa 3.2

# %% [markdown]
# ### 3.4 Com este modelo selecionado, execute um GridSearchCV testando pelo menos 3 hiperparâmetros diferentes para encontrar o ajuste ideal. Consultar os hiperparâmetros mais relevantes para o modelo e faixas/opções sugeridas para busca

# %% [markdown]
# ### 3.5 Fazer as predições deste melhor modelo no conjunto de teste separado (20%).

# %% [markdown]
# ### 3.6 Plote a Matriz de Confusão (ConfusionMatrixDisplay) e salve em .csv o nome do modelo selecionado, seus hiperparâmetros ótimos, e as métricas de acurácia, precisão, recall e f1.

# %% [markdown]
# ### 3.7 Envie este .csv para o Professor josenalde.oliveira@ufrn.br

# %% [markdown]
# ### 3.8 Pesquise como criar um pipeline de transformação de dados desde a ingestão em UI para exportar o melhor modelo em formato pickle, para integrar este modelo em UI no Streamlit
